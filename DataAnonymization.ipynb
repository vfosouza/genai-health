# %%
pip install syft tensorflow
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/vfosouza/Workspace/genai-health/genai-health-env/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the patient data
data = pd.read_csv("patient_data.csv")

print(data.head())
# Out:
#   Patient Name;Race;Gender;Age;Weight (lb);Height (inches)
# 0                                A;White;M;36;153;70
# 1                                B;Black;F;32;121;65
# 2                                C;White;F;55;117;63
# 3                                D;Black;F;23;115;69
# 4                                E;White;M;40;163;73

# %%
# Drop columns containing PII
anonymized_data = data.drop(columns=["  Patient Name"])

# Display anonymized data
print(anonymized_data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Drop columns containing PII
# ----> 2 anonymized_data = data.drop(columns=["  Patient Name"])
#       4 # Display anonymized data
#       5 print(anonymized_data.head())
#
# File ~/Workspace/genai-health/genai-health-env/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
